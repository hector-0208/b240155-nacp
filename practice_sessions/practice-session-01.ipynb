# %% [markdown]
# 1. Ask the user for their age. Subtract that age from the current year (2026) to tell them
#    which year they were born.

# %%
age = int(input("When were you born? "))
print(f"You were born in the year {2026 - age}")
# Out:
# You were born in the year 20

# %% [markdown]
# 2. Create two variables, a = 15 and b = 5. Print the result of their addition, subtraction,
#    multiplication, and division.

# %%
a, b = 15, 5
print(
    f"Addition: {a + b}, Subtraction: {a - b}, Division: {a / b}, Multiplication: {a * b}"
)
# Out:
# Addition: 20, Subtraction: 10, Division: 3.0, Multiplication: 75

# %% [markdown]
# 3. Create variables for your name, age, favorite_hobby, and location. Print them all in a
#    single sentence.

# %%
name = "Priyanshu Prasad"
age = 19
favourite_hobby = "Reading"
location = "Ravangla"
print(
    f"Name: {name}, Age: {age}, Favourite Hobby: {favourite_hobby}, Location: {location}"
)
# Out:
# Name: Priyanshu Prasad, Age: 19, Favourite Hobby: Reading, Location: Ravangla

# %% [markdown]
# 4. Create a program that asks for a temperature in Celsius and converts it to Fahrenheit
#    using the formula:F = (C \* 9/5) + 32

# %%
Celsius = int(input("Enter temperature in celsius: "))
Fahrenheit = (Celsius * 9 / 5) + 32
print(f"Fahrenheit: {Fahrenheit}")
# Out:
# Fahrenheit: 98.6

# %% [markdown]
# 5. Use the Simple Interest formula to calculate how much money someone will have in
#    the bank.Formula: A = P(1 + rt)
#    P = Principal amount (initial investment)
#    r = Annual interest rate (decimal)
#    t = Time in years
#    Goal: Create variables for P, r, and t, then calculate and print the final amount A.

# %%
principal = 1000
interest = 5 / 100
time = 3
Amount = principal * (1 + interest * time)
print(Amount)
# Out:
# 1150.0
