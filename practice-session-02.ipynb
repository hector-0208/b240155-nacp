# %% [markdown]
# Q. 1. Create the variables x = 2 and y = 3, then determine what each of the following statements
# displays:
# a) print('x =', x)
# b) print('Value of', x, '+', x, 'is', (x + x))
# c) print('x =')
# d) print((x + y), '=', (y + x))

# %%
x = 2
y = 3
print("x =", x)
print("Value of", x, "+", x, "is", (x + x))
print("x =")
print((x + y), "=", (y + x))
# Out:
# x = 2
# Value of 2 + 2 is 4
# x =
# 5 = 5

# %% [markdown]
# Q. 2. Write a Python expression using the \*\* operator to calculate the square root of 64.

# %%
print("Square root of 62 is", 64**0.5)
# Out:
# Square root of 62 is 8.0

# %% [markdown]
# Q. 3. Given the expression 10 \* 5 + 3, what is the result? How would you use parentheses to change
# the expression so it evaluates to 80?.

# %%
print(10 * 5 + 3)
print(10 * (5 + 3))
# Out:
# 53
# 80

# %% [markdown]
# Q. 4. Write a print statement using triple quotes that displays the following text exactly as shown:
# Display "hi" and 'bye' in quotes

# %%
print("""Display "hi" and 'bye' in quotes""")
# Out:
# Display "hi" and 'bye' in quotes

# %% [markdown]
# Q. 5. How can you split a single print statement over two lines in your code without causing a syntax
# error or adding a newline to the output?

# %%
print(
    "Split a single print statement\
over two lines without syntax error"
)
# Out:
# Split a single print statementover two lines without syntax error
